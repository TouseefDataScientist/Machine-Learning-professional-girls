# %% [markdown]
# # SABIKA SAMMAN

# %% [markdown]
# Data Scientist | Technical Assessor | Python Developer
#
# -  Email: sabikasamman23@gmail.com
# -  Phone: +92 310 5375537
# -  LinkedIn: https://www.linkedin.com/in/sabikasamman84/
# -  GitHub: https://github.com/SabikaSamman
# -  Kaggle: https://www.kaggle.com/sabikasabika

# %% [markdown]
# ## ABOUT
#
# I'm a computer science graduate currently pursuing further studies while
# working as a NAVTTC technical assessor in Python, AI, and data science.
# I have hands-on experience with machine learning, data analysis, and
# visualization. Seeking an entry-level data science role to build
# predictive models and work with real datasets.

# %% [markdown]
# ## Experience
#
# ### Freelance Data Science Projects
#
# - Built machine learning models using Python.
# - Cleaned and analyzed datasets.
# - Performed exploratory data analysis.
# - Created data visualizations.
# - Evaluated machine learning models using different performance metrics.
#
# ### National Assessor
#
# National Vocational & Technical Training Commission (NAVTTC)
#
# - Conduct competency-based assessments.
# - Evaluate candidates according to NAVTTC assessment standards.
# - Maintain assessment records and prepare assessment reports.

# %% [markdown]
# ## Education
#
# - Bachelor of Accounting & Finance (Currently Enrolled), Allama Iqbal Open University (AIOU)
# - Bachelor of Science (Mathematics & Computer Science), University of the Punjab
# - Higher Secondary School Certificate (Computer Science), FBISE
# - Secondary School Certificate (Computer Science), FBISE

# %% [markdown]
# ## Certifications & Training
#
# - **Certificate in Computer Applications (CCA)**
#   - TEVTA (3 Months)
#
# - **High Impact IT Training (HIIT)**
#   - Joint Venture of NAVTTC and Ministry of Federal Education and Professional Training (6 Months)
#   - Modules Completed:
#     - Blockchain Development (2 Months)
#     - Data Science and Machine Learning (2 Months)
#     - Artificial Intelligence (2 Months)
#
# - **IBM Python 101 for Data Science**
#   - IBM Cognitive Class
#
# - **NAVTTC National Assessor**
#
# - **Python Essentials 1**
#   - Cisco Networking Academy

# %% [markdown]
# ## Technical Skills
#
# - **Programming Languages:** Python
#
# - **Data Science & Analysis:**
#   - Data Cleaning
#   - Exploratory Data Analysis (EDA)
#   - Feature Engineering
#   - Statistical Analysis
#
# - **Machine Learning:**
#   - Linear Regression
#   - Logistic Regression
#   - Support Vector Machine (SVM)
#   - Decision Trees
#   - Random Forest
#
# - **Libraries & Tools:**
#   - Pandas
#   - NumPy
#   - Matplotlib
#   - Seaborn
#   - Jupyter Notebook

# %% [markdown]
# ## SOFT SKILLS
#
# - Clear Communication
# - Problem Solving
# - Attention to Detail
# - Teamwork and Collaboration
# - Time Management
# - Critical Thinking
# - Ability to Learn Quickly

# %% [markdown]
# ## LANGUAGES
#
# - English
# - Urdu

# %% [markdown]
# ## Achievements
#
# - Certified as a NAVTTC National Assessor.
# - Secured 2nd Position in NAVTTC High Impact IT Training (HIIT).
# - Successfully completed IBM Python 101 for Data Science.
# - Completed multiple machine learning and data analysis projects.

# %% [markdown]
# ## Professional Interests
#
# - Continuous learning in Data Science, Machine Learning, and Artificial Intelligence.
# - Reading technology blogs, research papers, and industry articles.
# - Exploring new AI tools and emerging technologies.
