# %% [markdown]
# # SABIKA SAMMAN

# %% [markdown]
# **Data Scientist | Technical Assessor | Python Developer**

# %% [markdown]
# - **Email:** sabikasamman23@gmail.com
# - **Phone:** +92 310 5375537
# - **LinkedIn:** https://www.linkedin.com/in/sabikasamman84/
# - **GitHub:** https://github.com/SabikaSamman
# - **Kaggle:** https://www.kaggle.com/sabikasabika

# %% [markdown]
# ## ABOUT
#
# Computer Science graduate currently pursuing a Bachelor's in Accounting & Finance while working as a **NAVTTC National Technical Assessor** in Python, Artificial Intelligence, and Data Science. Hands-on experience in machine learning, data analysis, data visualization, and predictive modeling using Python. Passionate about solving real-world problems with data and seeking an entry-level Data Scientist or Machine Learning role.

# %% [markdown]
# ## EXPERIENCE
#
# ### Freelance Data Science Projects
#
# - Built machine learning models using Python and Scikit-learn.
# - Cleaned, transformed, and analyzed real-world datasets.
# - Performed Exploratory Data Analysis (EDA).
# - Created visualizations using Matplotlib and Seaborn.
# - Evaluated models using appropriate regression and classification metrics.
#
# ### National Technical Assessor
#
# **National Vocational & Technical Training Commission (NAVTTC)**
#
# - Conduct competency-based technical assessments.
# - Evaluate candidates according to NAVTTC assessment standards.
# - Prepare assessment reports and maintain assessment records.
# - Assess Python, Artificial Intelligence, and Data Science competencies.

# %% [markdown]
# ## EDUCATION
#
# - **Bachelor of Accounting & Finance** *(Currently Enrolled)*
#   - Allama Iqbal Open University (AIOU)
#
# - **Bachelor of Science (Mathematics & Computer Science)**
#   - University of the Punjab
#
# - **Higher Secondary School Certificate (Computer Science)**
#   - FBISE
#
# - **Secondary School Certificate (Computer Science)**
#   - FBISE

# %% [markdown]
# ## CERTIFICATIONS & TRAINING
#
# - **Certificate in Computer Applications (CCA)**
#   - TEVTA (3 Months)
#
# - **High Impact IT Training (HIIT)**
#   - Joint Venture of NAVTTC & Ministry of Federal Education and Professional Training (6 Months)
#
#   **Modules Completed**
#   - Blockchain Development
#   - Data Science & Machine Learning
#   - Artificial Intelligence
#
# - **IBM Python 101 for Data Science**
#   - IBM Cognitive Class
#
# - **NAVTTC National Assessor**
#
# - **Python Essentials 1**
#   - Cisco Networking Academy

# %% [markdown]
# ## TECHNICAL SKILLS
#
# ### Programming Languages
#
# - Python
#
# ### Data Science & Analytics
#
# - Data Cleaning
# - Exploratory Data Analysis (EDA)
# - Feature Engineering
# - Statistical Analysis
#
# ### Machine Learning
#
# - Linear Regression
# - Logistic Regression
# - Support Vector Machine (SVM)
# - Decision Trees
# - Random Forest
#
# ### Libraries & Tools
#
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Jupyter Notebook

# %% [markdown]
# ## SOFT SKILLS
#
# - Communication
# - Problem Solving
# - Critical Thinking
# - Teamwork
# - Time Management
# - Attention to Detail
# - Quick Learner

# %% [markdown]
# ## LANGUAGES
#
# - English
# - Urdu

# %% [markdown]
# ## ACHIEVEMENTS
#
# - Certified NAVTTC National Assessor.
# - Secured **2nd Position** in NAVTTC High Impact IT Training (HIIT).
# - Successfully completed IBM Python 101 for Data Science.
# - Completed multiple machine learning and data analysis projects.

# %% [markdown]
# ## PROFESSIONAL INTERESTS
#
# - Data Science
# - Machine Learning
# - Artificial Intelligence
# - Predictive Analytics
# - Continuous Learning
# - Research in Emerging Technologies
