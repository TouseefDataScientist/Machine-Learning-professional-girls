# %%
pip install azure-ai-textanalytics core
# Out:
# Requirement already satisfied: azure-ai-textanalytics in c:\Users\Dell\AppData\Local\Programs\Python\Python314\Lib\site-packages (5.4.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement core (from versions: none)
# ERROR: No matching distribution found for core

# %%
pip install azure-core azure-ai-textanalytics
# Out:
# Requirement already satisfied: azure-core in c:\Users\Dell\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.41.0)
# Requirement already satisfied: azure-ai-textanalytics in c:\Users\Dell\AppData\Local\Programs\Python\Python314\Lib\site-packages (5.4.0)
# Requirement already satisfied: requests>=2.21.0 in c:\Users\Dell\AppData\Local\Programs\Python\Python314\Lib\site-packages (from azure-core) (2.34.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in C:\Users\Dell\AppData\Roaming\Python\Python314\site-packages (from azure-core) (4.16.0)
# Requirement already satisfied: azure-common>=1.1 in c:\Users\Dell\AppData\Local\Programs\Python\Python314\Lib\site-packages (from azure-ai-textanalytics) (1.1.28)
# Requirement already satisfied: isodate>=0.6.1 in c:\Users\Dell\AppData\Local\Programs\Python\Python314\Lib\site-packages (from azure-ai-textanalytics) (0.7.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Dell\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.21.0->azure-core) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\Dell\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.21.0->azure-core) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\Dell\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.21.0->azure-core) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\Users\Dell\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.21.0->azure-core) (2026.6.17)
# Note: you may need to restart the kernel to use updated packages.

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient

# %%
# 1. Your Azure Details (Endpoint and Key)
endpoint = "https://cit-04.cognitiveservices.azure.com/"
key = "DIWhvLd8U0bzPlqhkzyg1eLdjOAP6yZsQJIdzz4wtW3smHWACWNvJQQJ99CGACYeBjFXJ3w3AAAaACOGKRTv"

# %%
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient

# 1. Your Azure Details (Endpoint and Key)
endpoint = "https://cit-04.cognitiveservices.azure.com/"
key = "DIWhvLd8U0bzPlqhkzyg1eLdjOAP6yZsQJIdzz4wtW3smHWACWNvJQQJ99CGACYeBjFXJ3w3AAAaACOGKRTv" 

# Authenticating the client
def authenticate_client():
    ta_credential = AzureKeyCredential(key)
    text_analytics_client = TextAnalyticsClient(
            endpoint=endpoint, 
            credential=ta_credential)
    return text_analytics_client

def main():
    client = authenticate_client()
    
    # 2. Input text to analyze
    documents = ["Graphic design is a versatile, interdisciplinary field where art and technology meet to communicate ideas, solve problems, and build brand identity. Professionals shape consumer experiences across print, digital, and environmental media using typography, color theory, and layout strategies"]
    
    # Sentiment Analysis (Positive, Negative, or Neutral)
    print("--- Running Sentiment Analysis ---")
    sentiment_result = client.analyze_sentiment(documents=documents)[0]
    print(f"Overall Sentiment: {sentiment_result.sentiment.upper()}")
    print(f"Scores: Positive={sentiment_result.confidence_scores.positive:.2f}; Neutral={sentiment_result.confidence_scores.neutral:.2f}; Negative={sentiment_result.confidence_scores.negative:.2f}\n")
    
    # Key Phrases Extraction (Extracting important words/topics)
    print("--- Extracting Key Phrases ---")
    key_phrase_result = client.extract_key_phrases(documents=documents)[0]
    if not key_phrase_result.is_error:
        print("Key Phrases:")
        for phrase in key_phrase_result.key_phrases:
            print(f" - {phrase}")
    else:
        print(f"Error: {key_phrase_result.error}")

if __name__ == "__main__":
    main()
# Out:
# --- Running Sentiment Analysis ---
# Overall Sentiment: NEUTRAL
# Scores: Positive=0.00; Neutral=0.99; Negative=0.00
#
# --- Extracting Key Phrases ---
# Key Phrases:
#  - versatile, interdisciplinary field
#  - Graphic design
#  - brand identity
#  - consumer experiences
#  - environmental media
#  - color theory
#  - layout strategies
#  - art
#  - technology
#  - ideas
#  - problems
#  - Professionals
#  - typography
