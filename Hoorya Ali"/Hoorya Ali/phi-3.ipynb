# %%
https://integer.services.ai.azure.com/models/chat/completions?api-version=2024-05-01-preview

# %%
from openai import OpenAI

endpoint = "https://integer.services.ai.azure.com/openai/v1/"
model_name = "Phi-4-mini-reasoning"
deployment_name = "Phi-4-mini-reasoning"

api_key = "<your-api-key>"

client = OpenAI(
    base_url=f"{endpoint}",
    api_key=api_key
)

completion = client.chat.completions.create(
    model=deployment_name,
    messages=[
        {
            "role": "user",
            "content": "What is the capital of France?",
        }
    ],
)

print(completion.choices[0].message)

# %%
print(completion.choices[0].message.content)
